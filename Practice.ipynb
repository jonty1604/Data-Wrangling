# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
df=pd.read_csv('IPL Matches 2008-2020.csv')

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df=df[[#'id', 'city',
    'date', 'player_of_match', 'venue',
    # 'neutral_venue',
       'team1', 'team2', 'toss_winner', 
    'toss_decision', 'winner', 'result',
       'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2']].copy()

# %%
df
# Out:
#            date player_of_match                                       venue  \
# 0    2008-04-18     BB McCullum                       M Chinnaswamy Stadium
# 1    2008-04-19      MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2    2008-04-19     MF Maharoof                            Feroz Shah Kotla
# 3    2008-04-20      MV Boucher                            Wankhede Stadium
# 4    2008-04-20       DJ Hussey                                Eden Gardens
# ..          ...             ...                                         ...
# 811  2020-09-28  AB de Villiers         Dubai International Cricket Stadium
# 812  2020-11-05       JJ Bumrah         Dubai International Cricket Stadium
# 813  2020-11-06   KS Williamson                        Sheikh Zayed Stadium
# 814  2020-11-08      MP Stoinis                        Sheikh Zayed Stadium
# 815  2020-11-10        TA Boult         Dubai International Cricket Stadium
#
# ...

# %%
df.loc[df.duplicated(subset=['toss_winner','winner'])].reset_index(drop=True)
# Out:
#            date player_of_match                                       venue  \
# 0    2008-04-26       SR Watson                       M Chinnaswamy Stadium
# 1    2008-04-28        MS Dhoni                       M Chinnaswamy Stadium
# 2    2008-05-01     SA Asnodkar                      Sawai Mansingh Stadium
# 3    2008-05-03       IK Pathan  Punjab Cricket Association Stadium, Mohali
# 4    2008-05-05     S Sreesanth                       M Chinnaswamy Stadium
# ..          ...             ...                                         ...
# 681  2020-09-28  AB de Villiers         Dubai International Cricket Stadium
# 682  2020-11-05       JJ Bumrah         Dubai International Cricket Stadium
# 683  2020-11-06   KS Williamson                        Sheikh Zayed Stadium
# 684  2020-11-08      MP Stoinis                        Sheikh Zayed Stadium
# 685  2020-11-10        TA Boult         Dubai International Cricket Stadium
#
# ...

# %%
df.isna().sum()
# Out:
# date                 0
# player_of_match      4
# venue                0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df=df.loc[~df.player_of_match.isna()] \
.reset_index(drop=True) \
.copy()

df
# Out:
#            date player_of_match                                       venue  \
# 0    2008-04-18     BB McCullum                       M Chinnaswamy Stadium
# 1    2008-04-19      MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2    2008-04-19     MF Maharoof                            Feroz Shah Kotla
# 3    2008-04-20      MV Boucher                            Wankhede Stadium
# 4    2008-04-20       DJ Hussey                                Eden Gardens
# ..          ...             ...                                         ...
# 807  2020-09-28  AB de Villiers         Dubai International Cricket Stadium
# 808  2020-11-05       JJ Bumrah         Dubai International Cricket Stadium
# 809  2020-11-06   KS Williamson                        Sheikh Zayed Stadium
# 810  2020-11-08      MP Stoinis                        Sheikh Zayed Stadium
# 811  2020-11-10        TA Boult         Dubai International Cricket Stadium
#
# ...

# %%
df.isna().sum()
# Out:
# date                 0
# player_of_match      0
# venue                0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               0
# result               0
# result_margin       13
# eliminator           0
# method             793
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df.eliminator.value_counts()
# Out:
# N    799
# Y     13
# Name: eliminator, dtype: int64

# %%
df[df.eliminator=='Y']
# Out:
#            date player_of_match                                      venue  \
# 66   2009-04-23       YK Pathan                                   Newlands
# 130  2010-03-21        J Theron            MA Chidambaram Stadium, Chepauk
# 327  2013-04-07       GH Vihari  Rajiv Gandhi International Stadium, Uppal
# 340  2013-04-16         V Kohli                      M Chinnaswamy Stadium
# 415  2014-04-29     JP Faulkner                       Sheikh Zayed Stadium
# 475  2015-04-21        SE Marsh               Sardar Patel Stadium, Motera
# 607  2017-04-29       KH Pandya     Saurashtra Cricket Association Stadium
# 702  2019-03-30         PP Shaw                           Feroz Shah Kotla
# 742  2019-05-02       JJ Bumrah                           Wankhede Stadium
# 753  2020-09-20      MP Stoinis        Dubai International Cricket Stadium
# 772  2020-10-18     LH Ferguson                       Sheikh Zayed Stadium
# ...

# %%
df.head()
# Out:
#          date player_of_match                                       venue  \
# 0  2008-04-18     BB McCullum                       M Chinnaswamy Stadium
# 1  2008-04-19      MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2  2008-04-19     MF Maharoof                            Feroz Shah Kotla
# 3  2008-04-20      MV Boucher                            Wankhede Stadium
# 4  2008-04-20       DJ Hussey                                Eden Gardens
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# 3               Mumbai Indians  Royal Challengers Bangalore
# 4        Kolkata Knight Riders              Deccan Chargers
#
#                    toss_winner toss_decision                       winner  \
# 0  Royal Challengers Bangalore         field        Kolkata Knight Riders
# ...

# %%
df.toss_winner.value_counts() \
    .head(8) \
    .plot(kind='bar' , title='toss winners')
# Out:
# <Axes: title={'center': 'toss winners'}>

# %%
df.result_margin.plot(kind='hist' , bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.query('toss_winner == winner') \
    .groupby('venue')['winner'] \
    .agg(['count'])['count'] \
    .sort_values(ascending=False)
# Out:
# venue
# Eden Gardens                                            43
# Feroz Shah Kotla                                        38
# Wankhede Stadium                                        37
# M Chinnaswamy Stadium                                   35
# MA Chidambaram Stadium, Chepauk                         30
# Sawai Mansingh Stadium                                  25
# Rajiv Gandhi International Stadium, Uppal               21
# Punjab Cricket Association Stadium, Mohali              16
# Sheikh Zayed Stadium                                    15
# Maharashtra Cricket Association Stadium                 14
# Dubai International Cricket Stadium                     11
# Punjab Cricket Association IS Bindra Stadium, Mohali    11
# Sharjah Cricket Stadium                                  9
# Kingsmead                                                9
# Dr DY Patil Sports Academy                               9
# Subrata Roy Sahara Stadium                               9
# ...
